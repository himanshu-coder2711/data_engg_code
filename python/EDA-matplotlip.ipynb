# %%
#matplotlib
#seaborn-visualization library based on matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sales=pd.read_csv('Sales_Data.csv')
df_loan=pd.read_csv('loandata.csv')
df_titanic=pd.read_csv('Titanic.csv')

# %%
df_sales.head()
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
# 2       Offline              C  09-12-2011  478051030.0   9/29/2011
# 3       Offline              L   5/13/2010  892599952.0   6/15/2010
# 4       Offline              C   7/20/2015  571902596.0   7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %%
#count values
df_sales['Region'].value_counts()
# Out:
# Europe                               1330
# Sub-Saharan Africa                   1285
# Asia                                  719
# Middle East and North Africa          610
# Central America and the Caribbean     534
# Australia and Oceania                 416
# North America                         106
# Name: Region, dtype: int64

# %%
#ploting the above data in graph
df_sales['Region'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_sales['Country'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_sales['Item_Type'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_sales['Sales_Channel'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_sales['Order_Priority'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#count plot using seaborn
sns.countplot(x='Region',data=df_sales)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.title('Number of oreders by Region')
sns.countplot(x='Region',data=df_sales)
plt.xlabel('Region')
plt.ylabel('Number of orders')
plt.xticks(rotation=90)
plt.show()

# %%
df_sales['Region'].value_counts().plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='Region'>

# %%
df_sales['Item_Type'].value_counts().plot.pie(autopct='%2f%%')
# Out:
# <Axes: ylabel='Item_Type'>

# %%
df_sales['Sales_Channel'].value_counts().plot.pie(autopct='%2f%%')
# Out:
# <Axes: ylabel='Sales_Channel'>

# %%
df_sales['Order_Priority'].value_counts().plot.pie(autopct='%2f%%')
# Out:
# <Axes: ylabel='Order_Priority'>

# %%
data=pd.DataFrame(df_sales['Region'].value_counts())
data
# Out:
#                                    Region
# Europe                               1330
# Sub-Saharan Africa                   1285
# Asia                                  719
# Middle East and North Africa          610
# Central America and the Caribbean     534
# Australia and Oceania                 416
# North America                         106

# %%
plt.pie(data['Region'],labels=data.index,autopct='%2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x17ab31e90>,
# ...
#  [Text(0.7377541274679345, 0.8159159560910835, 'Europe'),
#   Text(-0.8670481828229847, 0.6769249948578945, 'Sub-Saharan Africa'),
#   Text(-0.9101769185130295, -0.6177199826831946, 'Asia'),
#   Text(-0.15293826117160236, -1.0893162480518717, 'Middle East and North Africa'),
#   Text(0.6021910643604981, -0.9205248079244636, 'Central America and the Caribbean'),
#   Text(1.0154722216018264, -0.42286660681005744, 'Australia and Oceania'),
#   Text(1.0975612171585085, -0.07320774951829408, 'North America')],
#  [Text(0.40241134225523695, 0.4450450669587728, '26.600000%'),
#   Text(-0.47293537244890066, 0.3692318153770333, '25.700000%'),
#   Text(-0.4964601373707433, -0.3369381723726516, '14.380001%'),
#   Text(-0.08342086972996492, -0.5941724989373846, '12.200000%'),
#   Text(0.3284678532875444, -0.502104440686071, '10.680000%'),
#   Text(0.5538939390555415, -0.23065451280548582, '8.320000%'),
# ...

# %%
#add colors to it
colors=sns.color_palette('bright')[0:8]
plt.pie(data['Region'],labels=data.index,colors=colors,autopct='%.0f##')
plt.show()

# %%
data=pd.DataFrame(df_sales['Order_Priority'].value_counts())
print(data)
plt.pie(data['Order_Priority'],labels=data.index,colors=colors,autopct='%.0f%%')
plt.show()
# Out:
#    Order_Priority
# M            1321
# H            1278
# L            1227
# C            1174

# %%
data=pd.DataFrame(df_sales['Item_Type'].value_counts())
print(data)
plt.pie(data['Item_Type'],labels=data.index,colors=colors,autopct='%.0f%%')
plt.show()
# Out:
#                  Item_Type
# Fruits                 447
# Beverages              446
# Baby Food              445
# Cosmetics              423
# Household              423
# Office Supplies        418
# Personal Care          413
# Vegetables             409
# Meat                   399
# Snacks                 397
# Clothes                385
# Cereal                 384

# %%
data=pd.DataFrame(df_sales['Country'].value_counts())
print(data)
plt.pie(data['Country'],labels=data.index,colors=colors,autopct='%.0f%%')
plt.show()
# Out:
#                           Country
# San Marino                     40
# Andorra                        40
# Ghana                          38
# Mauritius                      38
# United States of America       38
# ...                           ...
# Dominica                       18
# Angola                         16
# Mongolia                       15
# Cape Verde                     14
# Monaco                         13
#
# [185 rows x 1 columns]

# %%
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
sns.countplot(x='Age',data=df_titanic)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Sex',data=df_titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#Histogram
df_titanic['Age'].hist()
# Out:
# <Axes: >

# %%
plt.hist(df_titanic.Age)
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
df_sales=pd.read_csv('Sales_Data.csv')
df_loan=pd.read_csv('loandata.csv')
df_titanic=pd.read_csv('Titanic.csv')

# %%
plt.hist(df_titanic['Age'])
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
df_titanic.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
sns.distplot(df_titanic['Age'],kde=False)
df.title('Histogram of  Age')
plt.show()
# Out:
# /var/folders/94/zpf80p8s4mb6q77mpbs78srr0000gn/T/ipykernel_4672/2437523018.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_titanic['Age'],kde=False)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 sns.distplot(df_titanic['Age'],kde=False)
# ----> 2 df.title('Histogram of  Age')
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
df_loan.boxplot(column='LoanAmount')
# Out:
# <Axes: >

# %%
sns.boxplot(df_loan['LoanAmount'])
# Out:
# <Axes: >

# %%
df_sales.head()
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
# 2       Offline              C  09-12-2011  478051030.0   9/29/2011
# 3       Offline              L   5/13/2010  892599952.0   6/15/2010
# 4       Offline              C   7/20/2015  571902596.0   7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %%
sns.boxplot(df_sales['Units_Sold'])
# Out:
# <Axes: >

# %%
sns.boxplot(df_sales['Unit_SellingPrice'])
# Out:
# <Axes: >

# %%
sns.boxplot(df_sales['Unit_MakingCost'])
# Out:
# <Axes: >

# %%
sns.boxplot(df_sales['Total_Revenue'])
# Out:
# <Axes: >

# %%
sns.distplot(df_sales['Units_Sold'],kde=False)
df.title('Histogram of  Units_Sold')
plt.show()
# Out:
# /var/folders/94/zpf80p8s4mb6q77mpbs78srr0000gn/T/ipykernel_4672/370739596.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_sales['Units_Sold'],kde=False)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 sns.distplot(df_sales['Units_Sold'],kde=False)
# ----> 2 df.title('Histogram of  Units_Sold')
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(df_sales['Total_Revenue'])
plt.xlabel('Total_Revenue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sns.boxplot(df_sales['Total_Revenue'],xlabel='Total_Revenue')
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2239, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     ax = plt.gca()
#    2237 kwargs.update(dict(whis=whis))
# -> 2239 plotter.plot(ax, kwargs)
#    2240 return ax
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:888, in _BoxPlotter.plot(self, ax, boxplot_kws)
#     886 def plot(self, ax, boxplot_kws):
#     887     """Make the plot."""
# --> 888     self.draw_boxplot(ax, boxplot_kws)
#     889     self.annotate_axes(ax)
#     890     if self.orient == "h":
#
# ...

# %%
sns.countplot(x='Units_Sold',data=df_sales)
# Out:
# <Axes: xlabel='Units_Sold', ylabel='count'>

# %%
#bivariant data analysis
#numerical vs numerical

df_loan.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
#plot between applicant income and loan amount
plt.scatter(df_loan.ApplicantIncome,df_loan.LoanAmount)

# %%
#corlation
df_loan.ApplicantIncome.corr(df_loan.LoanAmount)
# Out:
# 0.5709090389885669

# %%
plt.scatter(df_loan.ApplicantIncome,df_loan.CoapplicantIncome)

# %%
df_loan.ApplicantIncome.corr(df_loan.CoapplicantIncome)
# Out:
# -0.11660458122889969

# %%
df_sales.head()
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
# 2       Offline              C  09-12-2011  478051030.0   9/29/2011
# 3       Offline              L   5/13/2010  892599952.0   6/15/2010
# 4       Offline              C   7/20/2015  571902596.0   7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %%
plt.scatter(df_sales.Units_Sold,df_sales.Unit_SellingPrice)

# %%
df_sales.Units_Sold.corr(df_sales.Unit_SellingPrice)
# Out:
# -0.01749166697631486

# %%
plt.scatter(df_sales.Unit_SellingPrice,df_sales.Unit_MakingCost)

# %%
df_sales.Unit_SellingPrice.corr(df_sales.Unit_MakingCost)
# Out:
# 0.9862309527482878

# %%
#total revenue and total cost and total profit
sns.pairplot(data=df_sales,vars=['Total_Revenue','Total_Cost','Total_Profit'])
plt.show()

# %%
#coefficient corelation beween two different variable
df_loan.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df_loan[['ApplicantIncome','CoapplicantIncome','LoanAmount']].corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000

# %%
#Hearmap for colour
sns.heatmap(df_loan[['ApplicantIncome','CoapplicantIncome','LoanAmount']].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df_loan.corr(),annot=True)
plt.show()
# Out:
# /var/folders/94/zpf80p8s4mb6q77mpbs78srr0000gn/T/ipykernel_4672/4029867611.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_loan.corr(),annot=True)

# %%
#line plot x-axis
df_sales['Order_Date_Updated']=pd.to_datetime(df_sales['Order_Date'])

# %%
df_sales.head()
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
# 2       Offline              C  09-12-2011  478051030.0   9/29/2011
# 3       Offline              L   5/13/2010  892599952.0   6/15/2010
# 4       Offline              C   7/20/2015  571902596.0   7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %%
df_sales.groupby('Item_Type')['Total_Profit'].mean()
# Out:
# Item_Type
# Baby Food          490053.768674
# Beverages           77420.476816
# Cereal             448940.898750
# Clothes            376821.784519
# Cosmetics          878245.320733
# Fruits              12621.946376
# Household          822229.627636
# Meat               272552.552381
# Office Supplies    636166.501196
# Personal Care      129037.277288
# Snacks             266050.916675
# Vegetables         322094.044914
# Name: Total_Profit, dtype: float64

# %%
sns.barplot(x='Item_Type',y='Total_Profit',data=df_sales)
plt.xticks(rotation=90)
plt.show()

# %%
#total profit on fruits is low
#total profit on cosmetics is high
sns.barplot(y='Item_Type',x='Total_Profit',data=df_sales,orient='h')
plt.xticks(rotation=90)
plt.show()

# %%
#categorical to categorical
crosstab=pd.crosstab(df_loan['Gender'],df_loan['Loan_Status'])
crosstab
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
crosstab.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Gender'>

# %%
#multivariant analysis
sns.lineplot(x='Item_Type',y='Unit_Sold',hue='Order_Priority',data=df_sales)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 #multivariant analysis
# ----> 2 sns.lineplot(x='Item_Type',y='Unit_Sold',hue='Order_Priority',data=df_sales)
#       3 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     622     legend=legend,
# ...

# %%
sns.lineplot(x='Order_Year',y='Unit_Sold',hue='Region',data=df_sales)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.lineplot(x='Order_Year',y='Unit_Sold',hue='Region',data=df_sales)
#       2 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     622     legend=legend,
#     623 )
# ...

# %%
sns.scatterplot(x=df_loan['ApplicantIncome'],y=df_loan['LoanAmount'])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
sns.scatterplot(x='ApplicantIncome',y='LoanAmount',hue='Gender',data=df_loan)
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
#to save the plot
sns.scatterplot(x='ApplicantIncome',y='LoanAmount',hue='Gender',data=df_loan)
plt.savefig('LoanInfo.png')

# %%
fig,axs=plt.subplots(figsize=(15,6),ncols=2,nrows=2)
sns.boxplot(x=df_sale['Sales_Channel'],y=df_sales['Unit_Sold'],ax=axs[0][0])
sns.boxplot(x=df_sale['Sales_Channel'],y=df_sales['Unit_SellingPrice'],ax=axs[0][1])
sns.boxplot(x=df_sale['Sales_Channel'],y=df_sales['Unit_SellingPrice'],ax=axs[1][0])
sns.boxplot(x=df_sale['Sales_Channel'],y=df_sales['Unit_SellingPrice'],ax=axs[1][1])

# %%
#multiple graph using for loop
cat_col=['Gender','Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']
for col in cat_col:
    sns.countplot(x=col,data=df_loan)
    plt.show()

# %%
#catplot
sns.catplot(x='Gender',y='ApplicantIncome',data=df_loan)

# %%
sns.catplot(x='Gender',data=df_loan,kind='count')

# %%
sns.catplot(x='Property_Area',data=df_loan,kind='count')

# %%
cat_order=['Rular','urban','Semiurban']
sns.catplot(x='Gender',data=df_loan,kind='count',order=cat_order)

# %%
sns.catplot(x='Item_Type',y='Total_Profit',data=df_sales,kind='bar',ci=None)
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/94/zpf80p8s4mb6q77mpbs78srr0000gn/T/ipykernel_1211/722442055.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x='Item_Type',y='Total_Profit',data=df_sales,kind='bar',ci=None)

# %%
df_loan.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...
